# %%
import pandas as pd
import numpy as np
import altair as alt

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn import metrics

# %%
# %run -i columns.py
# %run -i helper_functions.py

# %%
def split_X_Y(df: pd.DataFrame, output_col: str):
    cols = set(df.columns)
    independent_cols = set(URBANIZATION_INDICATORS + ANTI_URBANIZATION_INDICATORS)
    mutual = cols.intersection(independent_cols)
    independent_vars = df[list(mutual)]

    dependent_cols = list(cols - independent_cols)
    dependent_vars = df[output_col]

    return independent_vars, dependent_vars

# %%
def create_train_test_sets(df: pd.DataFrame, indicators: list):
    columns = ['Country', 'Country code', 'Dystopia residual', 'Residual-to-happiness ratio'] + indicators
    df = df[columns] 
    
    threshold = 0.5
    df_thresh = df.dropna(axis=1, thresh=int(df.shape[0] * threshold))

    df_impute = df_thresh.fillna(df_thresh.mean())
    df_impute
    
    train, test = train_test_split(df_impute, test_size=0.2)
    
    return train, test

# %%
class LinearRegressionModel():
    def __init__(self, train: pd.DataFrame, test: pd.DataFrame, output_label: str):
        self.output_label = output_label
        
        self.train = train
        self.test = test
        self.X, self.Y = split_X_Y(train.copy(), output_label)
        self.x, self.y = split_X_Y(test.copy(), output_label)
        
        self.model = LinearRegression()
        self.model.fit(self.X, self.Y)
        self.predictions = self.model.predict(self.x)
        
    def get_predictions_table(self) -> pd.DataFrame:
        table = pd.DataFrame(self.x.copy())
        table[f'Predicted {self.output_label}'] = self.predictions
        table[f'Actual {self.output_label}'] = self.y
        
        return table
    
    def get_coefficients_table(self) -> pd.DataFrame:
        coefficients = pd.DataFrame(self.X.columns, columns=['variable'])
        coefficients['coefficient'] = self.model.coef_

        return coefficients
    
    def get_intercept(self) -> float:
        return self.model.intercept_
    
    def get_r_squared(self) -> float:
        return self.model.score(self.x, self.y)
    
    def get_mean_squared_error(self) -> float:
        return metrics.mean_squared_error(self.y, self.predictions)
    
    def get_scree_plot(self) -> alt.Chart:
        k = len(self.X.columns)
        
        scaled_values = StandardScaler().fit(self.X).transform(self.X)
        pca = PCA(n_components=k).fit(scaled_values)
        
        scree_plot_data = pd.DataFrame()
        scree_plot_data['indices'] = np.arange(k) + 1
        scree_plot_data['var_explained'] = pca.explained_variance_ratio_
        
        return alt.Chart(scree_plot_data, title='Scree plot').mark_line().encode(
            x=alt.X('indices', title='Principal component'),
            y=alt.Y('var_explained', title='Variance explained')
        )
    
    def get_pca_chart(self, k: int) -> alt.Chart:
        inputs = pd.concat([self.X.copy(), self.x.copy()])
        outputs = pd.concat([self.Y.copy(), self.y.copy()])
        
        scaled_inputs = StandardScaler().fit(inputs).transform(inputs)
        pca = PCA(n_components=k).fit(scaled_inputs)
        
        results = pd.DataFrame()
        
        for i in range(len(pca.components_)):
            results[f'PC{i}'] = pca.components_[i]
            
        results[self.output_label] = outputs
        
        return alt.Chart(results).mark_point().encode(
            x='PC0',
            y=self.output_label
        ).interactive()

# %%
data = pd.read_csv('tmp/developing_countries.csv')

# Calculate the percentage of unexplained happiness for each happiness score
data['Residual-to-happiness ratio'] = data['Dystopia residual'] / data['Happiness score']

# %% [markdown]
# # Analysis of the Effects of Urbanization on the Dystopia Residual

# %%
train, test = create_train_test_sets(data.copy(), URBANIZATION_INDICATORS)
# Out:
# C:\Users\rekak\AppData\Local\Temp\ipykernel_14648\3036349688.py:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_impute = df_thresh.fillna(df_thresh.mean())

# %% [markdown]
# **Prediction of Dystopia Residual-to-Happiness Ratio Using Positive Indicators of Urbanization**

# %%
urbanization_residual_ratio = LinearRegressionModel(train.copy(), test.copy(), 'Residual-to-happiness ratio')

# %%
urbanization_residual_ratio.get_scree_plot()
# Out:
# C:\Users\rekak\anaconda3\envs\test\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
urbanization_residual_ratio.get_pca_chart(1)
# Out:
# C:\Users\rekak\anaconda3\envs\test\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
urbanization_residual_ratio.get_predictions_table()
# Out:
#      Employment in services (% of total employment) (modeled ILO estimate)  \
# 359                                          21.113001
# 201                                          56.056999
# 394                                          26.576000
# 411                                          53.723000
# 139                                          52.215000
# ..                                                 ...
# 102                                          64.168999
# 38                                           58.535000
# 114                                          66.605003
# 354                                          54.362999
# 264                                          48.000999
#
#      Manufacturing, value added (% of GDP)  \
# 359                              12.666669
# 201                              15.621025
# 394                              12.666669
# 411                              16.598631
# 139                              17.073523
# ..                                     ...
# 102                              12.400894
# 38                               22.221599
# 114                              12.476185
# 354                              12.666669
# 264                              11.895015
#
#      Air transport, freight (million ton-km)  \
# 359                               985.946746
# 201                                 3.217000
# 394                               985.946746
# 411                              3493.930482
# 139                               985.946746
# ..                                       ...
# 102                              1316.795809
# 38                                  1.670000
# 114                                 0.582750
# 354                               985.946746
# 264                                 0.489630
#
#      Employment in industry (% of total employment) (modeled ILO estimate)  \
# 359                                           6.435000
# 201                                          24.483999
# 394                                           7.073000
# 411                                          26.775999
# 139                                           9.938000
# ..                                                 ...
# 102                                          19.825001
# 38                                           30.768000
# 114                                          26.416000
# 354                                          13.606000
# 264                                          17.848000
#
#      Urban population (% of total)  \
# 359                      43.816000
# 201                      55.696000
# 394                      55.169177
# 411                      74.134000
# 139                      88.976000
# ..                             ...
# 102                      79.764000
# 38                       78.134000
# 114                      56.667000
# 354                      55.169177
# 264                      42.490000
#
#      Commercial bank branches (per 100,000 adults)  \
# 359                                      13.890841
# 201                                      29.766144
# 394                                      13.890841
# 411                                      18.139831
# 139                                      13.890841
# ..                                             ...
# 102                                      15.908311
# 38                                        0.783214
# 114                                      32.502855
# 354                                      13.890841
# 264                                      27.544485
#
#      Individuals using the Internet (% of population)  \
# 359                                          1.880000
# 201                                         65.317025
# 394                                         42.805461
# 411                                         58.347734
# 139                                         50.320120
# ..                                                ...
# 102                                         55.904973
# 38                                          74.436445
# 114                                         67.096192
# 354                                         42.805461
# 264                                         69.000000
#
#      Air transport, passengers carried  \
# 359                       4.486000e+03
# 201                       2.427047e+06
# 394                       1.814317e+07
# 411                       1.003665e+08
# 139                       1.814317e+07
# ..                                 ...
# 102                       3.090972e+07
# 38                        2.493100e+06
# 114                       2.057804e+06
# 354                       1.814317e+07
# 264                       1.005936e+06
#
#      Industry (including construction), value added per worker (constant 2010 US$)  \
# 359                                       23036.702831
# 201                                       16140.396982
# 394                                       23036.702831
# 411                                       41270.763008
# 139                                      156610.225372
# ..                                                 ...
# 102                                       23243.456126
# 38                                        14876.356458
# 114                                       31460.108633
# 354                                       23036.702831
# 264                                        5799.129088
#
#      Predicted Residual-to-happiness ratio  Actual Residual-to-happiness ratio
# 359                               0.508780                            0.705463
# 201                               0.347035                            0.494863
# 394                               0.470230                            0.190130
# 411                               0.383995                            0.425077
# 139                               0.387811                            0.296286
# ..                                     ...                                 ...
# 102                               0.407463                            0.441156
# 38                                0.364803                            0.309433
# 114                               0.319064                            0.350367
# 354                               0.422734                            0.437487
# 264                               0.364669                            0.527614
#
# [92 rows x 11 columns]

# %%
urbanization_residual_ratio.get_coefficients_table()
# Out:
#                                             variable   coefficient
# 0  Employment in services (% of total employment)... -9.504456e-04
# 1              Manufacturing, value added (% of GDP) -2.604089e-04
# 2            Air transport, freight (million ton-km) -1.953100e-06
# 3  Employment in industry (% of total employment)... -3.227659e-03
# 4                      Urban population (% of total)  1.190509e-03
# 5      Commercial bank branches (per 100,000 adults) -8.832980e-04
# 6   Individuals using the Internet (% of population) -1.201188e-03
# 7                  Air transport, passengers carried  2.395372e-10
# 8  Industry (including construction), value added... -5.905131e-07

# %%
urbanization_residual_ratio.get_r_squared()
# Out:
# 0.21320409040445065

# %%
urbanization_residual_ratio.get_mean_squared_error()
# Out:
# 0.010812451457616253

# %% [markdown]
# **Prediction of Dystopia Residual Values Using Positive Indicators of Urbanization**

# %%
urbanization_residual_value = LinearRegressionModel(train.copy(), test.copy(), 'Dystopia residual')

# %%
urbanization_residual_value.get_scree_plot()
# Out:
# C:\Users\rekak\anaconda3\envs\test\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
urbanization_residual_value.get_pca_chart(1)
# Out:
# C:\Users\rekak\anaconda3\envs\test\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
urbanization_residual_value.get_predictions_table()
# Out:
#      Employment in services (% of total employment) (modeled ILO estimate)  \
# 418                                          21.511000
# 21                                           50.617001
# 193                                          61.425999
# 354                                          54.362999
# 145                                          46.137001
# ..                                                 ...
# 206                                          57.484001
# 451                                          35.173000
# 40                                           69.795998
# 396                                          45.159000
# 348                                          70.540001
#
#      Manufacturing, value added (% of GDP)  \
# 418                               8.704258
# 21                               10.284650
# 193                              10.275409
# 354                              12.666669
# 145                              11.367037
# ..                                     ...
# 206                              12.666669
# 451                               7.552274
# 40                                6.503924
# 396                              27.390641
# 348                              12.907130
#
#      Air transport, freight (million ton-km)  \
# 418                                 0.023472
# 21                                985.946746
# 193                                37.669008
# 354                               985.946746
# 145                                 0.844630
# ..                                       ...
# 206                                 7.355192
# 451                                81.557610
# 40                                  2.689022
# 396                              2160.069653
# 348                               833.991000
#
#      Employment in industry (% of total employment) (modeled ILO estimate)  \
# 418                                           7.152000
# 21                                           15.784000
# 193                                          20.562000
# 354                                          13.606000
# 145                                          18.684999
# ..                                                 ...
# 206                                          25.298000
# 451                                          10.636000
# 40                                           15.152000
# 396                                          23.677000
# 348                                          24.490000
#
#      Urban population (% of total)  \
# 418                      22.060000
# 21                       63.082000
# 193                      57.191000
# 354                      55.169177
# 145                      54.086000
# ..                             ...
# 206                      55.942000
# 451                      42.976000
# 40                       45.495000
# 396                      48.448000
# 348                      83.401000
#
#      Commercial bank branches (per 100,000 adults)  \
# 418                                       2.901283
# 21                                       23.098070
# 193                                       2.966006
# 354                                      13.890841
# 145                                       7.120122
# ..                                             ...
# 206                                      28.226565
# 451                                       4.513118
# 40                                       20.424837
# 396                                      12.375701
# 348                                       8.579537
#
#      Individuals using the Internet (% of population)  \
# 418                                         17.834859
# 21                                          64.346030
# 193                                         70.829934
# 354                                         42.805461
# 145                                         31.447852
# ..                                                ...
# 206                                         70.330836
# 451                                         27.852579
# 40                                          44.575740
# 396                                         47.504966
# 348                                         74.880000
#
#      Air transport, passengers carried  \
# 418                       4.181200e+04
# 21                        1.814317e+07
# 193                       5.081632e+06
# 354                       1.814317e+07
# 145                       3.904570e+05
# ..                                 ...
# 206                       2.442731e+06
# 451                       1.545730e+05
# 40                        9.904990e+05
# 396                       6.234168e+07
# 348                       3.509284e+07
#
#      Industry (including construction), value added per worker (constant 2010 US$)  \
# 418                                        4742.299696
# 21                                        23036.702831
# 193                                       37388.077128
# 354                                       23036.702831
# 145                                        5020.232317
# ..                                                 ...
# 206                                       15205.354928
# 451                                       12562.920681
# 40                                         9243.607206
# 396                                       16632.365708
# 348                                      129977.259876
#
#      Predicted Dystopia residual  Actual Dystopia residual
# 418                     1.910112                  1.427660
# 21                      2.125995                  1.978640
# 193                     2.026208                  2.247290
# 354                     2.159745                  2.026000
# 145                     2.153496                  2.309190
# ..                           ...                       ...
# 206                     1.959904                  1.947084
# 451                     2.074138                  1.826705
# 40                      2.129207                  3.080390
# 396                     1.995886                  2.579600
# 348                     1.838088                  2.614820
#
# [92 rows x 11 columns]

# %%
urbanization_residual_value.get_r_squared()
# Out:
# -0.027105666981012355

# %%
urbanization_residual_ratio.get_predictions_table()
# Out:
#      Employment in services (% of total employment) (modeled ILO estimate)  \
# 418                                          21.511000
# 21                                           50.617001
# 193                                          61.425999
# 354                                          54.362999
# 145                                          46.137001
# ..                                                 ...
# 206                                          57.484001
# 451                                          35.173000
# 40                                           69.795998
# 396                                          45.159000
# 348                                          70.540001
#
#      Manufacturing, value added (% of GDP)  \
# 418                               8.704258
# 21                               10.284650
# 193                              10.275409
# 354                              12.666669
# 145                              11.367037
# ..                                     ...
# 206                              12.666669
# 451                               7.552274
# 40                                6.503924
# 396                              27.390641
# 348                              12.907130
#
#      Air transport, freight (million ton-km)  \
# 418                                 0.023472
# 21                                985.946746
# 193                                37.669008
# 354                               985.946746
# 145                                 0.844630
# ..                                       ...
# 206                                 7.355192
# 451                                81.557610
# 40                                  2.689022
# 396                              2160.069653
# 348                               833.991000
#
#      Employment in industry (% of total employment) (modeled ILO estimate)  \
# 418                                           7.152000
# 21                                           15.784000
# 193                                          20.562000
# 354                                          13.606000
# 145                                          18.684999
# ..                                                 ...
# 206                                          25.298000
# 451                                          10.636000
# 40                                           15.152000
# 396                                          23.677000
# 348                                          24.490000
#
#      Urban population (% of total)  \
# 418                      22.060000
# 21                       63.082000
# 193                      57.191000
# 354                      55.169177
# 145                      54.086000
# ..                             ...
# 206                      55.942000
# 451                      42.976000
# 40                       45.495000
# 396                      48.448000
# 348                      83.401000
#
#      Commercial bank branches (per 100,000 adults)  \
# 418                                       2.901283
# 21                                       23.098070
# 193                                       2.966006
# 354                                      13.890841
# 145                                       7.120122
# ..                                             ...
# 206                                      28.226565
# 451                                       4.513118
# 40                                       20.424837
# 396                                      12.375701
# 348                                       8.579537
#
#      Individuals using the Internet (% of population)  \
# 418                                         17.834859
# 21                                          64.346030
# 193                                         70.829934
# 354                                         42.805461
# 145                                         31.447852
# ..                                                ...
# 206                                         70.330836
# 451                                         27.852579
# 40                                          44.575740
# 396                                         47.504966
# 348                                         74.880000
#
#      Air transport, passengers carried  \
# 418                       4.181200e+04
# 21                        1.814317e+07
# 193                       5.081632e+06
# 354                       1.814317e+07
# 145                       3.904570e+05
# ..                                 ...
# 206                       2.442731e+06
# 451                       1.545730e+05
# 40                        9.904990e+05
# 396                       6.234168e+07
# 348                       3.509284e+07
#
#      Industry (including construction), value added per worker (constant 2010 US$)  \
# 418                                        4742.299696
# 21                                        23036.702831
# 193                                       37388.077128
# 354                                       23036.702831
# 145                                        5020.232317
# ..                                                 ...
# 206                                       15205.354928
# 451                                       12562.920681
# 40                                         9243.607206
# 396                                       16632.365708
# 348                                      129977.259876
#
#      Predicted Residual-to-happiness ratio  Actual Residual-to-happiness ratio
# 418                               0.499603                            0.363180
# 21                                0.403227                            0.453817
# 193                               0.359693                            0.383824
# 354                               0.426580                            0.437487
# 145                               0.451730                            0.498422
# ..                                     ...                                 ...
# 206                               0.337318                            0.360905
# 451                               0.481994                            0.404676
# 40                                0.385800                            0.517191
# 396                               0.387511                            0.398455
# 348                               0.287681                            0.409911
#
# [92 rows x 11 columns]

# %% [markdown]
# # Analysis of the Effects of Negative Indicators of Urbanization on the Dystopia Residual

# %%
train, test = create_train_test_sets(data.copy(), ANTI_URBANIZATION_INDICATORS)
# Out:
# C:\Users\rekak\AppData\Local\Temp\ipykernel_14648\3036349688.py:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_impute = df_thresh.fillna(df_thresh.mean())

# %% [markdown]
# **Prediction of Dystopia Residual-to-Happiness Ratio Using Negative Indicators of Urbanization**

# %%
neg_urbanization_residual_ratio = LinearRegressionModel(train.copy(), test.copy(), 'Residual-to-happiness ratio')

# %%
neg_urbanization_residual_ratio.get_predictions_table()
# Out:
#      Agriculture, forestry, and fishing, value added per worker (constant 2010 US$)  \
# 85                                         1071.264748
# 367                                       19126.126853
# 237                                         263.781805
# 444                                       20761.228907
# 228                                       20761.228907
# ..                                                 ...
# 430                                       25383.026756
# 169                                        1512.488951
# 429                                       23018.482878
# 423                                        4654.288886
# 165                                       21938.835427
#
#      Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 85                                           46.575001
# 367                                           4.818000
# 237                                          68.602997
# 444                                          39.796001
# 228                                           8.281000
# ..                                                 ...
# 430                                           8.224000
# 169                                          45.558998
# 429                                           8.824000
# 423                                          15.600000
# 165                                           4.900000
#
#      Predicted Residual-to-happiness ratio  Actual Residual-to-happiness ratio
# 85                                0.441748                            0.497049
# 367                               0.350147                            0.402768
# 237                               0.490379                            0.582070
# 444                               0.427473                            0.283559
# 228                               0.357855                            0.363340
# ..                                     ...                                 ...
# 430                               0.357894                            0.408157
# 169                               0.439519                            0.498386
# 429                               0.359135                            0.357968
# 423                               0.373450                            0.347054
# 165                               0.350429                            0.258487
#
# [92 rows x 4 columns]

# %%
neg_urbanization_residual_ratio.get_r_squared()
# Out:
# 0.23803636427672292

# %%
neg_urbanization_residual_ratio.get_scree_plot()
# Out:
# C:\Users\rekak\anaconda3\envs\test\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
neg_urbanization_residual_ratio.get_pca_chart(1)
# Out:
# C:\Users\rekak\anaconda3\envs\test\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# **Prediction of Dystopia Residual Values Using Positive Indicators of Urbanization**

# %%
neg_urbanization_residual_value = LinearRegressionModel(train.copy(), test.copy(), 'Dystopia residual')

# %%
neg_urbanization_residual_value.get_r_squared()
# Out:
# -0.0019275269788932015

# %%
neg_urbanization_residual_value.get_scree_plot()
# Out:
# C:\Users\rekak\anaconda3\envs\test\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
neg_urbanization_residual_value.get_pca_chart(1)
# Out:
# C:\Users\rekak\anaconda3\envs\test\lib\site-packages\altair\utils\core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)
