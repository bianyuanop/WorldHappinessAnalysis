# %%
import pandas as pd
import numpy as np
import altair as alt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# %run -i columns.py
# %run -i helper_functions.py

# %%
def split_X_Y(df: pd.DataFrame, output_col: str):
    cols = set(df.columns)
    independent_cols = set(URBANIZATION_INDICATORS + ANTI_URBANIZATION_INDICATORS)
    mutual = cols.intersection(independent_cols)
    independent_vars = df[list(mutual)]

    dependent_cols = list(cols - independent_cols)
    dependent_vars = df[output_col]

    return independent_vars, dependent_vars

# %%
def create_train_test_sets(df: pd.DataFrame, indicators: list):
    columns = ['Country', 'Country code', 'Dystopia residual', 'Residual-to-happiness ratio'] + indicators
    df = df[columns] 
    
    threshold = 0.5
    df_thresh = df.dropna(axis=1, thresh=int(df.shape[0] * threshold))

    df_impute = df_thresh.fillna(df_thresh.mean())
    df_impute
    
    train, test = train_test_split(df_impute, test_size=0.2)
    
    return train, test

# %%
class LinearRegressionModel():
    def __init__(self, train: pd.DataFrame, test: pd.DataFrame, output_label: str):
        self.output_label = output_label
        
        self.train = train
        self.test = test
        self.X, self.Y = split_X_Y(train.copy(), output_label)
        self.x, self.y = split_X_Y(test.copy(), output_label)
        
        self.model = LinearRegression()
        self.model.fit(self.X, self.Y)
        self.predictions = self.model.predict(self.x)
        
    def get_predictions_table(self) -> pd.DataFrame:
        table = pd.DataFrame(self.x.copy())
        table[f'Predicted {self.output_label}'] = self.predictions
        table[f'Actual {self.output_label}'] = self.y
        
        return table
    
    def get_coefficients_table(self) -> pd.DataFrame:
        coefficients = pd.DataFrame(self.X.columns, columns=['variable'])
        coefficients['coefficient'] = self.model.coef_

        return coefficients
    
    def get_intercept(self) -> float:
        return self.model.intercept_
    
    def get_r_squared(self) -> float:
        return self.model.score(self.x, self.y)
    
    def get_mean_squared_error(self) -> float:
        return metrics.mean_squared_error(self.y, self.predictions)

# %%
data = pd.read_csv('tmp/developing_countries.csv')

# Calculate the percentage of unexplained happiness for each happiness score
data['Residual-to-happiness ratio'] = data['Dystopia residual'] / data['Happiness score']

# %% [markdown]
# # Analysis of the Effects of Urbanization on the Dystopia Residual

# %%
train, test = create_train_test_sets(data.copy(), URBANIZATION_INDICATORS)
# Out:
# C:\Users\rekak\AppData\Local\Temp\ipykernel_1200\3036349688.py:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_impute = df_thresh.fillna(df_thresh.mean())

# %% [markdown]
# **Prediction of Dystopia Residual-to-Happiness Ratio Using Positive Indicators of Urbanization**

# %%
urbanization_residual_ratio = LinearRegressionModel(train.copy(), test.copy(), 'Residual-to-happiness ratio')

# %%
urbanization_residual_ratio.get_predictions_table()
# Out:
#      Air transport, freight (million ton-km)  \
# 151                                 0.546373
# 295                               985.946746
# 429                               985.946746
# 385                                 0.025671
# 455                                 0.665035
# ..                                       ...
# 175                              1056.044519
# 67                                  1.530950
# 456                               985.946746
# 434                               112.281730
# 339                              4761.047070
#
#      Employment in industry (% of total employment) (modeled ILO estimate)  \
# 151                                          20.898001
# 295                                          17.142000
# 429                                          20.464001
# 385                                          29.014999
# 455                                           7.254000
# ..                                                 ...
# 175                                          22.018000
# 67                                           29.895000
# 456                                           7.220000
# 434                                          30.171000
# 339                                          27.181000
#
#      Commercial bank branches (per 100,000 adults)  \
# 151                                      32.516634
# 295                                      11.118123
# 429                                      11.977660
# 385                                      13.890841
# 455                                       4.424425
# ..                                             ...
# 175                                      16.894976
# 67                                       60.136678
# 456                                      13.890841
# 434                                      27.958746
# 339                                      32.909283
#
#      Urban population (% of total)  Manufacturing, value added (% of GDP)  \
# 151                      50.680000                              18.002159
# 295                      58.090000                              13.761283
# 429                      95.045000                              13.242661
# 385                      53.500000                              12.666669
# 455                      32.237000                              11.017009
# ..                             ...                                    ...
# 175                      54.659000                              20.163900
# 67                       73.990000                              13.621081
# 456                      55.169177                              12.666669
# 434                      50.650000                              12.666669
# 339                      74.050000                              12.692212
#
#      Individuals using the Internet (% of population)  \
# 151                                         40.703049
# 295                                         24.571834
# 429                                         64.600000
# 385                                         34.253402
# 455                                         27.055488
# ..                                                ...
# 175                                         32.292442
# 67                                          56.656300
# 456                                         42.805461
# 434                                         46.791287
# 339                                         70.100000
#
#      Employment in services (% of total employment) (modeled ILO estimate)  \
# 151                                          49.785999
# 295                                          51.678001
# 429                                          70.711998
# 385                                          56.291000
# 455                                          25.673000
# ..                                                 ...
# 175                                          47.192001
# 67                                           63.249001
# 456                                          25.580999
# 434                                          36.148998
# 339                                          66.109001
#
#      Industry (including construction), value added per worker (constant 2010 US$)  \
# 151                                       10116.577532
# 295                                        6307.824070
# 429                                       32044.454777
# 385                                       23036.702831
# 455                                        5866.001706
# ..                                                 ...
# 175                                       16114.509592
# 67                                        14666.319798
# 456                                       23036.702831
# 434                                        4546.225803
# 339                                       25419.584577
#
#      Air transport, passengers carried  Predicted Residual-to-happiness ratio  \
# 151                       1.555240e+05                               0.409712
# 295                       1.814317e+07                               0.452880
# 429                       1.814317e+07                               0.414114
# 385                       1.756400e+04                               0.369547
# 455                       2.825390e+05                               0.482579
# ..                                 ...                                    ...
# 175                       1.102529e+08                               0.431048
# 67                        1.063498e+06                               0.377605
# 456                       1.814317e+07                               0.495924
# 434                       2.383631e+06                               0.399414
# 339                       7.684613e+07                               0.356668
#
#      Actual Residual-to-happiness ratio
# 151                            0.448387
# 295                            0.471342
# 429                            0.357968
# 385                            0.306636
# 455                            0.412379
# ..                                  ...
# 175                            0.271660
# 67                             0.213350
# 456                            0.367281
# 434                            0.391912
# 339                            0.397820
#
# [92 rows x 11 columns]

# %%
urbanization_residual_ratio.get_coefficients_table()
# Out:
#                                             variable   coefficient
# 0            Air transport, freight (million ton-km) -2.057576e-06
# 1  Employment in industry (% of total employment)... -3.516312e-03
# 2      Commercial bank branches (per 100,000 adults)  2.326344e-06
# 3                      Urban population (% of total)  1.922774e-03
# 4              Manufacturing, value added (% of GDP)  1.463437e-04
# 5   Individuals using the Internet (% of population) -1.036161e-03
# 6  Employment in services (% of total employment)... -1.809296e-03
# 7  Industry (including construction), value added... -8.607865e-07
# 8                  Air transport, passengers carried  1.023643e-10

# %%
urbanization_residual_ratio.get_r_squared()
# Out:
# 0.16807238653812961

# %%
urbanization_residual_ratio.get_mean_squared_error()
# Out:
# 0.007884241009609525

# %% [markdown]
# **Prediction of Dystopia Residual Values Using Positive Indicators of Urbanization**

# %%
urbanization_residual_value = LinearRegressionModel(train.copy(), test.copy(), 'Dystopia residual')

# %%
urbanization_residual_value.get_predictions_table()
# Out:
#      Air transport, freight (million ton-km)  \
# 151                                 0.546373
# 295                               985.946746
# 429                               985.946746
# 385                                 0.025671
# 455                                 0.665035
# ..                                       ...
# 175                              1056.044519
# 67                                  1.530950
# 456                               985.946746
# 434                               112.281730
# 339                              4761.047070
#
#      Employment in industry (% of total employment) (modeled ILO estimate)  \
# 151                                          20.898001
# 295                                          17.142000
# 429                                          20.464001
# 385                                          29.014999
# 455                                           7.254000
# ..                                                 ...
# 175                                          22.018000
# 67                                           29.895000
# 456                                           7.220000
# 434                                          30.171000
# 339                                          27.181000
#
#      Commercial bank branches (per 100,000 adults)  \
# 151                                      32.516634
# 295                                      11.118123
# 429                                      11.977660
# 385                                      13.890841
# 455                                       4.424425
# ..                                             ...
# 175                                      16.894976
# 67                                       60.136678
# 456                                      13.890841
# 434                                      27.958746
# 339                                      32.909283
#
#      Urban population (% of total)  Manufacturing, value added (% of GDP)  \
# 151                      50.680000                              18.002159
# 295                      58.090000                              13.761283
# 429                      95.045000                              13.242661
# 385                      53.500000                              12.666669
# 455                      32.237000                              11.017009
# ..                             ...                                    ...
# 175                      54.659000                              20.163900
# 67                       73.990000                              13.621081
# 456                      55.169177                              12.666669
# 434                      50.650000                              12.666669
# 339                      74.050000                              12.692212
#
#      Individuals using the Internet (% of population)  \
# 151                                         40.703049
# 295                                         24.571834
# 429                                         64.600000
# 385                                         34.253402
# 455                                         27.055488
# ..                                                ...
# 175                                         32.292442
# 67                                          56.656300
# 456                                         42.805461
# 434                                         46.791287
# 339                                         70.100000
#
#      Employment in services (% of total employment) (modeled ILO estimate)  \
# 151                                          49.785999
# 295                                          51.678001
# 429                                          70.711998
# 385                                          56.291000
# 455                                          25.673000
# ..                                                 ...
# 175                                          47.192001
# 67                                           63.249001
# 456                                          25.580999
# 434                                          36.148998
# 339                                          66.109001
#
#      Industry (including construction), value added per worker (constant 2010 US$)  \
# 151                                       10116.577532
# 295                                        6307.824070
# 429                                       32044.454777
# 385                                       23036.702831
# 455                                        5866.001706
# ..                                                 ...
# 175                                       16114.509592
# 67                                        14666.319798
# 456                                       23036.702831
# 434                                        4546.225803
# 339                                       25419.584577
#
#      Air transport, passengers carried  Predicted Dystopia residual  \
# 151                       1.555240e+05                     2.179257
# 295                       1.814317e+07                     2.192642
# 429                       1.814317e+07                     2.426974
# 385                       1.756400e+04                     1.922141
# 455                       2.825390e+05                     1.961975
# ..                                 ...                          ...
# 175                       1.102529e+08                     2.268750
# 67                        1.063498e+06                     2.375992
# 456                       1.814317e+07                     2.176198
# 434                       2.383631e+06                     1.980192
# 339                       7.684613e+07                     2.194992
#
#      Actual Dystopia residual
# 151                  2.893891
# 295                  2.824280
# 429                  2.321420
# 385                  1.061574
# 455                  1.597970
# ..                        ...
# 175                  1.429477
# 67                   0.899910
# 456                  1.356000
# 434                  2.346380
# 339                  2.273940
#
# [92 rows x 11 columns]

# %%
urbanization_residual_value.get_r_squared()
# Out:
# -0.07323286765571546

# %%
urbanization_residual_ratio.get_predictions_table()
# Out:
#      Air transport, freight (million ton-km)  \
# 151                                 0.546373
# 295                               985.946746
# 429                               985.946746
# 385                                 0.025671
# 455                                 0.665035
# ..                                       ...
# 175                              1056.044519
# 67                                  1.530950
# 456                               985.946746
# 434                               112.281730
# 339                              4761.047070
#
#      Employment in industry (% of total employment) (modeled ILO estimate)  \
# 151                                          20.898001
# 295                                          17.142000
# 429                                          20.464001
# 385                                          29.014999
# 455                                           7.254000
# ..                                                 ...
# 175                                          22.018000
# 67                                           29.895000
# 456                                           7.220000
# 434                                          30.171000
# 339                                          27.181000
#
#      Commercial bank branches (per 100,000 adults)  \
# 151                                      32.516634
# 295                                      11.118123
# 429                                      11.977660
# 385                                      13.890841
# 455                                       4.424425
# ..                                             ...
# 175                                      16.894976
# 67                                       60.136678
# 456                                      13.890841
# 434                                      27.958746
# 339                                      32.909283
#
#      Urban population (% of total)  Manufacturing, value added (% of GDP)  \
# 151                      50.680000                              18.002159
# 295                      58.090000                              13.761283
# 429                      95.045000                              13.242661
# 385                      53.500000                              12.666669
# 455                      32.237000                              11.017009
# ..                             ...                                    ...
# 175                      54.659000                              20.163900
# 67                       73.990000                              13.621081
# 456                      55.169177                              12.666669
# 434                      50.650000                              12.666669
# 339                      74.050000                              12.692212
#
#      Individuals using the Internet (% of population)  \
# 151                                         40.703049
# 295                                         24.571834
# 429                                         64.600000
# 385                                         34.253402
# 455                                         27.055488
# ..                                                ...
# 175                                         32.292442
# 67                                          56.656300
# 456                                         42.805461
# 434                                         46.791287
# 339                                         70.100000
#
#      Employment in services (% of total employment) (modeled ILO estimate)  \
# 151                                          49.785999
# 295                                          51.678001
# 429                                          70.711998
# 385                                          56.291000
# 455                                          25.673000
# ..                                                 ...
# 175                                          47.192001
# 67                                           63.249001
# 456                                          25.580999
# 434                                          36.148998
# 339                                          66.109001
#
#      Industry (including construction), value added per worker (constant 2010 US$)  \
# 151                                       10116.577532
# 295                                        6307.824070
# 429                                       32044.454777
# 385                                       23036.702831
# 455                                        5866.001706
# ..                                                 ...
# 175                                       16114.509592
# 67                                        14666.319798
# 456                                       23036.702831
# 434                                        4546.225803
# 339                                       25419.584577
#
#      Air transport, passengers carried  Predicted Residual-to-happiness ratio  \
# 151                       1.555240e+05                               0.409712
# 295                       1.814317e+07                               0.452880
# 429                       1.814317e+07                               0.414114
# 385                       1.756400e+04                               0.369547
# 455                       2.825390e+05                               0.482579
# ..                                 ...                                    ...
# 175                       1.102529e+08                               0.431048
# 67                        1.063498e+06                               0.377605
# 456                       1.814317e+07                               0.495924
# 434                       2.383631e+06                               0.399414
# 339                       7.684613e+07                               0.356668
#
#      Actual Residual-to-happiness ratio
# 151                            0.448387
# 295                            0.471342
# 429                            0.357968
# 385                            0.306636
# 455                            0.412379
# ..                                  ...
# 175                            0.271660
# 67                             0.213350
# 456                            0.367281
# 434                            0.391912
# 339                            0.397820
#
# [92 rows x 11 columns]

# %% [markdown]
# # Analysis of the Effects of Negative Indicators of Urbanization on the Dystopia Residual

# %%
train, test = create_train_test_sets(data.copy(), ANTI_URBANIZATION_INDICATORS)
# Out:
# C:\Users\rekak\AppData\Local\Temp\ipykernel_1200\3036349688.py:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_impute = df_thresh.fillna(df_thresh.mean())

# %% [markdown]
# **Prediction of Dystopia Residual-to-Happiness Ratio Using Negative Indicators of Urbanization**

# %%
neg_urbanization_residual_ratio = LinearRegressionModel(train.copy(), test.copy(), 'Residual-to-happiness ratio')

# %%
neg_urbanization_residual_ratio.get_r_squared()
# Out:
# 0.21309374936335967

# %% [markdown]
# **Prediction of Dystopia Residual Values Using Positive Indicators of Urbanization**

# %%
neg_urbanization_residual_value = LinearRegressionModel(train.copy(), test.copy(), 'Dystopia residual')

# %%
neg_urbanization_residual_value.get_r_squared()
# Out:
# -0.007702100806088907
