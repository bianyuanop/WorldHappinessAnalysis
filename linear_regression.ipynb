# %%
import pandas as pd
import numpy as np
import altair as alt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# %run -i columns.py
# %run -i helper_functions.py

# %%
df = pd.read_csv('tmp/developing_countries.csv')

df['Residual-to-happiness ratio'] = df['Dystopia residual'] / df['Happiness score']

# %%
columns = ['Country', 'Country code', 'Dystopia residual', 'Residual-to-happiness ratio'] + URBANIZATION_INDICATORS + ANTI_URBANIZATION_INDICATORS

df = df[columns] 
df
# Out:
#          Country Country code  Dystopia residual  Residual-to-happiness ratio  \
# 0    Afghanistan          AFG           1.952100                     0.546042
# 1    Afghanistan          AFG           2.145580                     0.638565
# 2    Afghanistan          AFG           2.150801                     0.566895
# 3    Afghanistan          AFG           2.196000                     0.604626
# 4        Albania          ALB           1.898940                     0.382928
# ..           ...          ...                ...                          ...
# 452       Zambia          ZMB           1.667000                     0.380854
# 453     Zimbabwe          ZWE           2.441910                     0.529698
# 454     Zimbabwe          ZWE           2.442700                     0.582566
# 455     Zimbabwe          ZWE           1.597970                     0.412379
# 456     Zimbabwe          ZWE           1.356000                     0.367281
#
#      Air transport, freight (million ton-km)  \
# 0                                  33.102039
# 1                                  29.010881
# 2                                  25.144211
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 452                                      NaN
# 453                                 0.796107
# 454                                 0.804947
# 455                                 0.665035
# 456                                      NaN
#
#      Air transport, passengers carried  \
# 0                            1929907.0
# 1                            1917924.0
# 2                            1858558.0
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 452                                NaN
# 453                           370165.0
# 454                           378803.0
# 455                           282539.0
# 456                                NaN
#
#      Annual freshwater withdrawals, industry (% of total freshwater withdrawal)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 452                                                NaN
# 453                                                NaN
# 454                                                NaN
# 455                                                NaN
# 456                                                NaN
#
#      CO2 emissions (metric tons per capita)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 452                                     NaN
# 453                                     NaN
# 454                                     NaN
# 455                                     NaN
# 456                                     NaN
#
#      Commercial bank branches (per 100,000 adults)  \
# 0                                         2.190994
# 1                                         2.138151
# 2                                         2.138151
# 3                                              NaN
# 4                                        21.851423
# ..                                             ...
# 452                                            NaN
# 453                                       5.165438
# 454                                       5.260135
# 455                                       4.424425
# 456                                            NaN
#
#      Employment in industry (% of total employment) (modeled ILO estimate)  \
# 0                                            17.646999
# 1                                            17.424999
# 2                                            17.457001
# 3                                            17.596001
# 4                                            18.617001
# ..                                                 ...
# 452                                          10.683000
# 453                                           7.290000
# 454                                           7.218000
# 455                                           7.254000
# 456                                           7.220000
#
#      ...  Railways, goods transported (million ton-km)  \
# 0    ...                                           NaN
# 1    ...                                           NaN
# 2    ...                                           NaN
# 3    ...                                           NaN
# 4    ...                                           NaN
# ..   ...                                           ...
# 452  ...                                           NaN
# 453  ...                                           NaN
# 454  ...                                           NaN
# 455  ...                                           NaN
# 456  ...                                           NaN
#
#      Railways, passengers carried (million passenger-km)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 452                                                NaN
# 453                                                NaN
# 454                                                NaN
# 455                                                NaN
# 456                                                NaN
#
#      Urban population (% of total)  \
# 0                           24.803
# 1                           25.020
# 2                           25.250
# 3                              NaN
# 4                           57.434
# ..                             ...
# 452                            NaN
# 453                         32.385
# 454                         32.296
# 455                         32.237
# 456                            NaN
#
#      Individuals using the Internet (% of population)  \
# 0                                            8.260000
# 1                                           10.595726
# 2                                           11.447688
# 3                                                 NaN
# 4                                           63.252933
# ..                                                ...
# 452                                               NaN
# 453                                         22.742818
# 454                                         23.119989
# 455                                         27.055488
# 456                                               NaN
#
#      Educational attainment, competed at least Bachelor's or equivalent, population 25+, total (%) (cumulative)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 452                                                NaN
# 453                                                NaN
# 454                                                NaN
# 455                                                NaN
# 456                                                NaN
#
#      Educational attainment, competed at least Master's or equivalent, population 25+, total (%) (cumulative)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 452                                                NaN
# 453                                                NaN
# 454                                                NaN
# 455                                                NaN
# 456                                                NaN
#
#      Agriculture, forestry, and fishing, value added per worker (constant 2010 US$)  \
# 0                                           921.359625
# 1                                           930.799951
# 2                                           928.592663
# 3                                                  NaN
# 4                                          5378.217225
# ..                                                 ...
# 452                                                NaN
# 453                                         294.738272
# 454                                         275.073784
# 455                                         294.061198
# 456                                                NaN
#
#      Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 452                                                NaN
# 453                                                NaN
# 454                                                NaN
# 455                                                NaN
# 456                                                NaN
#
#      Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 0                                            38.678001
# 1                                            38.818001
# 2                                            38.773998
# 3                                            38.588001
# 4                                            41.362999
# ..                                                 ...
# 452                                          53.916000
# 453                                          67.121002
# 454                                          67.192001
# 455                                          67.072998
# 456                                          67.198997
#
#      Forest area (% of land area)
# 0                        2.067825
# 1                        2.067825
# 2                             NaN
# 3                             NaN
# 4                       28.156934
# ..                            ...
# 452                           NaN
# 453                     36.350006
# 454                     35.542457
# 455                           NaN
# 456                           NaN
#
# [457 rows x 24 columns]

# %%
threshold = 0.5
df_thresh = df.dropna(axis=1, thresh=int(df.shape[0] * threshold))

df_impute = df_thresh.fillna(df_thresh.mean())
df_impute
# Out:
# C:\Users\rekak\AppData\Local\Temp\ipykernel_7660\3683817263.py:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_impute = df_thresh.fillna(df_thresh.mean())
#          Country Country code  Dystopia residual  Residual-to-happiness ratio  \
# 0    Afghanistan          AFG           1.952100                     0.546042
# 1    Afghanistan          AFG           2.145580                     0.638565
# 2    Afghanistan          AFG           2.150801                     0.566895
# 3    Afghanistan          AFG           2.196000                     0.604626
# 4        Albania          ALB           1.898940                     0.382928
# ..           ...          ...                ...                          ...
# 452       Zambia          ZMB           1.667000                     0.380854
# 453     Zimbabwe          ZWE           2.441910                     0.529698
# 454     Zimbabwe          ZWE           2.442700                     0.582566
# 455     Zimbabwe          ZWE           1.597970                     0.412379
# 456     Zimbabwe          ZWE           1.356000                     0.367281
#
#      Air transport, freight (million ton-km)  \
# 0                                  33.102039
# 1                                  29.010881
# 2                                  25.144211
# 3                                 985.946746
# 4                                 985.946746
# ..                                       ...
# 452                               985.946746
# 453                                 0.796107
# 454                                 0.804947
# 455                                 0.665035
# 456                               985.946746
#
#      Air transport, passengers carried  \
# 0                         1.929907e+06
# 1                         1.917924e+06
# 2                         1.858558e+06
# 3                         1.814317e+07
# 4                         1.814317e+07
# ..                                 ...
# 452                       1.814317e+07
# 453                       3.701650e+05
# 454                       3.788030e+05
# 455                       2.825390e+05
# 456                       1.814317e+07
#
#      Commercial bank branches (per 100,000 adults)  \
# 0                                         2.190994
# 1                                         2.138151
# 2                                         2.138151
# 3                                        13.890841
# 4                                        21.851423
# ..                                             ...
# 452                                      13.890841
# 453                                       5.165438
# 454                                       5.260135
# 455                                       4.424425
# 456                                      13.890841
#
#      Employment in industry (% of total employment) (modeled ILO estimate)  \
# 0                                            17.646999
# 1                                            17.424999
# 2                                            17.457001
# 3                                            17.596001
# 4                                            18.617001
# ..                                                 ...
# 452                                          10.683000
# 453                                           7.290000
# 454                                           7.218000
# 455                                           7.254000
# 456                                           7.220000
#
#      Employment in services (% of total employment) (modeled ILO estimate)  \
# 0                                            43.674999
# 1                                            43.756001
# 2                                            43.768002
# 3                                            43.816002
# 4                                            40.020000
# ..                                                 ...
# 452                                          35.401001
# 453                                          25.589001
# 454                                          25.590000
# 455                                          25.673000
# 456                                          25.580999
#
#      Industry (including construction), value added per worker (constant 2010 US$)  \
# 0                                          2079.555916
# 1                                          1999.566153
# 2                                          1923.393447
# 3                                         23036.702831
# 4                                         13648.254549
# ..                                                 ...
# 452                                       23036.702831
# 453                                        5962.002633
# 454                                        5930.642813
# 455                                        5866.001706
# 456                                       23036.702831
#
#      Manufacturing, value added (% of GDP)  Urban population (% of total)  \
# 0                                11.420006                      24.803000
# 1                                11.370465                      25.020000
# 2                                11.102526                      25.250000
# 3                                12.666669                      55.169177
# 4                                 5.671519                      57.434000
# ..                                     ...                            ...
# 452                              12.666669                      55.169177
# 453                              11.888599                      32.385000
# 454                              11.596020                      32.296000
# 455                              11.017009                      32.237000
# 456                              12.666669                      55.169177
#
#      Individuals using the Internet (% of population)  \
# 0                                            8.260000
# 1                                           10.595726
# 2                                           11.447688
# 3                                           42.805461
# 4                                           63.252933
# ..                                                ...
# 452                                         42.805461
# 453                                         22.742818
# 454                                         23.119989
# 455                                         27.055488
# 456                                         42.805461
#
#      Agriculture, forestry, and fishing, value added per worker (constant 2010 US$)  \
# 0                                           921.359625
# 1                                           930.799951
# 2                                           928.592663
# 3                                         20761.228907
# 4                                          5378.217225
# ..                                                 ...
# 452                                       20761.228907
# 453                                         294.738272
# 454                                         275.073784
# 455                                         294.061198
# 456                                       20761.228907
#
#      Employment in agriculture (% of total employment) (modeled ILO estimate)
# 0                                            38.678001
# 1                                            38.818001
# 2                                            38.773998
# 3                                            38.588001
# 4                                            41.362999
# ..                                                 ...
# 452                                          53.916000
# 453                                          67.121002
# 454                                          67.192001
# 455                                          67.072998
# 456                                          67.198997
#
# [457 rows x 15 columns]

# %%
train, test = train_test_split(df_impute, test_size=0.2)

# %%
def split_X_Y(df: pd.DataFrame, output_col: str):
    cols = set(df.columns)
    independent_cols = set(URBANIZATION_INDICATORS + ANTI_URBANIZATION_INDICATORS)
    mutual = cols.intersection(independent_cols)
    independent_vars = df[list(mutual)]

    dependent_cols = list(cols - independent_cols)
    dependent_vars = df[output_col]

    return independent_vars, dependent_vars

# %% [markdown]
# **First Model**

# %%
X, Y = split_X_Y(train, 'Residual-to-happiness ratio')
x, y = split_X_Y(test, 'Residual-to-happiness ratio')

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(x)

print(predictions)
print(y)
# Out:
# [0.37159091 0.39010878 0.45471947 0.38476213 0.41843284 0.43691599
#  0.38846796 0.39756472 0.45380724 0.43265947 0.41898203 0.4847718
#  0.4374836  0.50788341 0.22615218 0.39518922 0.38166993 0.39694178
#  0.47790871 0.38955828 0.4823943  0.41377409 0.34429139 0.35703576
#  0.4462481  0.39805272 0.42239325 0.49800402 0.29440753 0.4921976
#  0.51600373 0.41371737 0.38418351 0.46570829 0.47898986 0.43847495
#  0.35236644 0.43650207 0.41903023 0.35197464 0.37424277 0.35743874
#  0.35649193 0.40938872 0.29426472 0.41771817 0.43627898 0.40880066
#  0.44125118 0.3538456  0.43118917 0.4311105  0.43503491 0.43676071
#  0.52019688 0.37539839 0.40482687 0.38713211 0.37763509 0.37487907
#  0.46332872 0.35826119 0.42482568 0.33962914 0.40621945 0.39346927
#  0.43528451 0.36025377 0.33500014 0.39877261 0.48240259 0.50400558
#  0.45515955 0.44039939 0.40490134 0.45987166 0.37318918 0.39123828
#  0.42710821 0.50728496 0.44467058 0.40095948 0.46577715 0.39884692
#  0.37878287 0.50870637 0.49075734 0.30440686 0.45961993 0.39556295
#  0.39087049 0.39679264]
# 179    0.319423
# 414    0.337030
# 43     0.489006
# 67     0.213350
# 23     0.343439
#          ...
# 329    0.300975
# 452    0.380854
# 218    0.404248
# 289    0.289800
# 40     0.517191
# Name: Residual-to-happiness ratio, Length: 92, dtype: float64

# %%
coefficients = pd.DataFrame(X.columns, columns=['variable'])
coefficients['coefficient'] = model.coef_

coefficients
# Out:
#                                              variable   coefficient
# 0   Industry (including construction), value added... -6.707341e-07
# 1                   Air transport, passengers carried  2.615932e-11
# 2   Agriculture, forestry, and fishing, value adde...  1.566931e-08
# 3   Employment in industry (% of total employment)... -1.697379e+01
# 4             Air transport, freight (million ton-km)  1.042684e-06
# 5                       Urban population (% of total)  1.659291e-03
# 6               Manufacturing, value added (% of GDP)  6.856087e-04
# 7   Employment in services (% of total employment)... -1.697174e+01
# 8       Commercial bank branches (per 100,000 adults)  3.302430e-04
# 9   Employment in agriculture (% of total employme... -1.697025e+01
# 10   Individuals using the Internet (% of population) -1.181327e-03

# %%
model.intercept_
# Out:
# 1697.5345955468952

# %%
model.score(x, y)
# Out:
# 0.2462734484108534

# %%
metrics.mean_squared_error(y, predictions)
# Out:
# 0.010797915165883697

# %% [markdown]
# **Second Model**

# %%
X, Y = split_X_Y(train, 'Dystopia residual')
x, y = split_X_Y(test, 'Dystopia residual')

model = LinearRegression()
model.fit(X, Y)

predictions = model.predict(x)

print(predictions)
print(y)
# Out:
# [2.08076541 1.84124556 1.98230096 2.37715069 2.08163223 2.26229386
#  1.97963752 2.02362916 2.22985515 1.89191257 1.85027635 2.08731941
#  1.89636572 2.15198635 1.36831343 2.00330595 1.91305615 2.37748812
#  1.93301551 2.24673847 2.54053494 2.35562679 1.92122315 2.01727268
#  2.18345124 1.9993568  2.41893877 2.05727659 1.8384279  2.12626727
#  1.807436   2.16825482 2.03013118 2.11125779 2.17007184 1.89824758
#  2.01665034 1.91948329 1.99399664 2.02835254 2.00059912 2.0700518
#  1.79491669 2.32085759 1.83036536 2.21499023 1.92262054 1.91931872
#  2.07312716 1.91569225 1.89003569 1.91869498 2.20766851 2.28124028
#  1.96328507 2.32631909 2.04379666 1.98284456 1.59653872 1.98191828
#  2.0098057  1.98249279 2.24470047 1.86438378 2.3924925  2.13345533
#  2.09315477 1.8332863  1.8471535  2.11800166 2.10085369 1.78094348
#  2.10807781 2.08133295 2.28112762 1.89971137 1.89544287 2.08978584
#  1.86023705 1.8043269  2.23138954 1.89410685 1.90986462 2.0621292
#  2.15309928 1.99881274 1.83390737 1.90470715 2.10499357 2.33000937
#  2.062953   2.1241659 ]
# 179    1.498735
# 414    1.869840
# 43     1.633280
# 67     0.899910
# 23     1.484000
#          ...
# 329    1.797723
# 452    1.667000
# 218    2.073390
# 289    1.287000
# 40     3.080390
# Name: Dystopia residual, Length: 92, dtype: float64

# %%
coefficients = pd.DataFrame(X.columns, columns=['variable'])
coefficients['coefficient'] = model.coef_

coefficients
# Out:
#                                              variable   coefficient
# 0   Industry (including construction), value added... -3.633923e-06
# 1                   Air transport, passengers carried  9.152041e-10
# 2   Agriculture, forestry, and fishing, value adde...  1.792602e-07
# 3   Employment in industry (% of total employment)... -7.226738e+01
# 4             Air transport, freight (million ton-km) -6.497597e-06
# 5                       Urban population (% of total)  9.630363e-03
# 6               Manufacturing, value added (% of GDP)  1.020685e-02
# 7   Employment in services (% of total employment)... -7.225247e+01
# 8       Commercial bank branches (per 100,000 adults)  5.574521e-03
# 9   Employment in agriculture (% of total employme... -7.225500e+01
# 10   Individuals using the Internet (% of population) -2.069928e-03

# %%
model.intercept_
# Out:
# 7227.068158899305

# %%
model.score(x, y)
# Out:
# 0.020127820817355424

# %%
metrics.mean_squared_error(y, predictions)
# Out:
# 0.38501317695946613
